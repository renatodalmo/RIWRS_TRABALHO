# %%
import mysql
import mysql.connector

from IPython.core.display import display, HTML

import json

import requests

# %%
class googleMaps():
    def __init__(self):
        self.urlMaps = "http://maps.googleapis.com/maps/api/geocode/json?address="
        
    def pesquisa(self,endereco):
        status = "OVER_QUERY_LIMIT"
        
        while (status == "OVER_QUERY_LIMIT"):
            urlPesquisa = self.urlMaps + endereco
            endereco = requests.get(urlPesquisa, allow_redirects=True)
            conteudoEnd = endereco.content
            conteudoEnd = json.loads(conteudoEnd)
            status = conteudoEnd['status']
            
        return conteudoEnd

# %%
objGoogleMaps = googleMaps()
retorno = objGoogleMaps.pesquisa("Risde Attie")

# %%
#Classe de conexao ao banco de dados mysql
class bancoMysql():
    def __init__(self):
        global cnx
        
    def abreConexao(self):
        import mysql

        #configuração do servidor
        config = {
            'user': 'root',
            'password': '12345678',
            'host': 'localhost',
            'database': 'eleicoes',
            'raise_on_warnings': True
        }    
        #conectando na base
        self.cnx = mysql.connector.connect(**config)
        
    def executaQueryGenerica(self,cnx,sqlQuery,parametros):
        #cria cursor para execução e parse
        cursor = self.cnx.cursor()
        cursor.execute(sqlQuery,parametros)
        self.cnx.commit()
        cursor.close()
        return True;        
    
    def getAllRows(self,sql,parametros):
        cursor = self.cnx.cursor(dictionary=True)
        query = (sql)
        cursor.execute(query,parametros)
        arrDados = cursor.fetchall()
        cursor.close()
        return arrDados

    def fechaConexao(self):
        self.cnx.close()

# %%
objBanco = bancoMysql()
objBanco.abreConexao()

# %%
sql = """
        SELECT
            date_format(T1.dt_cadastro, '%Y%m%d%H') dt_cadastro_f,
            SUBSTR(t1.twitter,56,19) AS ID_TWITTER,
            t1.twitter
        FROM 
            eleicoes.tb_twitter t1
"""
parametros = ()

# %%
arrDados = objBanco.getAllRows(sql,parametros)
objBanco.fechaConexao()

# %%
arrTwiiterLocation = []
for rowDados in arrDados:
    twitter = json.loads(rowDados['twitter'])
    if 'user' in twitter.keys():
        #if 'location' in twitter.keys():
        arrTwiiterLocation.append(twitter['user'])

# %%
objGoogleMaps = googleMaps()

for rowTwiiterLocation in arrTwiiterLocation:
    
    if rowTwiiterLocation['location'] is not None:
        endereco = rowTwiiterLocation['location']
        retorno = objGoogleMaps.pesquisa(endereco)
        if (retorno['status'] == 'OK'):
            print(retorno['results'][0]['address_components'][1]['short_name'])
# Out:
# Uberlândia
# São Paulo
# PR
# SP
# 6417
# Ithaca
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-241-bd9e1ec6d999> in <module>()
#       7         retorno = objGoogleMaps.pesquisa(endereco)
#       8         if (retorno['status'] == 'OK'):
# ----> 9             print(retorno['results'][0]['address_components'][1]['short_name'])
#
# IndexError: list index out of range

# %%
arrLocais = []
x = 0


    
    
    
    retorno = objGoogleMaps.pesquisa("Risde Attie")
    
    urlMaps = "http://maps.googleapis.com/maps/api/geocode/json?address="
    urlMaps += rowTwiiterLocation['location']
    error_message = "inicio"

    while (error_message != ""):
        endereco = requests.get(urlMaps, allow_redirects=True)
        conteudoEnd = endereco.content
        conteudoEnd = json.loads(conteudoEnd)

        if conteudoEnd['results'] != []:
            arrTwiiterLocation.append(conteudoEnd['results'][0])
            error_message = ""
            x += 1
        else:
            if (conteudoEnd['status'] == 'OVER_QUERY_LIMIT'):
                error_message = 'OVER_QUERY_LIMIT'
            else:
                print(conteudoEnd)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-364-9c275af67fd0> in <module>()
#      10         endereco = requests.get(urlMaps, allow_redirects=True)
#      11         conteudoEnd = endereco.content
# ---> 12         conteudoEnd = json.loads(conteudoEnd)
#      13
#      14         if conteudoEnd['results'] != []:
#
# C:\Miniconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# C:\Miniconda3\lib\json\decoder.py in decode(self, s, _w)
#     337
#     338         """
# ...

# %%
for rowTwiiterLocation in arrTwiiterLocation:
    rowTwiiterLocation['']
# Out:
# [{'contributors_enabled': False,
#   'created_at': 'Sat Apr 04 02:48:07 +0000 2009',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': None,
#   'favourites_count': 6,
#   'follow_request_sent': None,
#   'followers_count': 46,
#   'following': None,
#   'friends_count': 90,
#   'geo_enabled': False,
#   'id': 28722914,
#   'id_str': '28722914',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 0,
#   'location': 'Uberlândia',
#   'name': 'Renato Dalmo',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1113276559/Imagem0299_normal.jpg',
# ...

# %%
strHtml = """

        <script type='text/javascript' src='https://www.gstatic.com/charts/loader.js'></script>
        <script type='text/javascript'>
          google.charts.load('current', {
            'packages':['geochart'],
            // Note: you will need to get a mapsApiKey for your project.
            // See: https://developers.google.com/chart/interactive/docs/basic_load_libs#load-settings
            'mapsApiKey': 'AIzaSyAHd1divgI7vvAsFdWXrjkck5ne-CTqALk'
          });
          google.charts.setOnLoadCallback(drawRegionsMap);

          function drawRegionsMap() {
            var data = google.visualization.arrayToDataTable([
              ['provinces', 'Popularity'],
              ['Sao Paulo', 50],
              ['Minas Gerais', 100],
              ['Rio de Janeiro', 100],
              ['Parana', 28],
              ['Amazonas', 16],
              ['Paraiba', 14],
              ['Bahia', 150],
              ['Argentina', 200]
            ]);

            var options = {
                region: 'BR',
                resolution: 'provinces',
                colorAxis: {
                  colors: ['#474AB4']
                }			

                //datalessRegionColor: '#E5E5E5'
            };

            var chart = new google.visualization.GeoChart(document.getElementById('regions_div'));

            chart.draw(data, options);
          }
        </script>

        <div id='regions_div' style='width: 900px; height: 500px;'></div>
"""
display(HTML(strHtml))
